# %%
import numpy as np
import matplotlib.pyplot as plt

from Experiment import Experiment
from algorithms import Greedy, SoftmaxPolicy, UCB, ThompsonSampling, Reinforce, UCB1_Normal
from utils import create_inverse_schedule
from metrics import MeanCummulativeRegret, PercentOptimalArmPull, AverageRegretOverTime
from reward_distributions import Normal
import Distribution
# Out:
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/utkarsh/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# # Bernoulli Reward Distribution
# ## Number of Arms K=2

# %%
algo = {
    "$\epsilon=0.3$-Greedy": (Greedy, {"eps": 0.3}),
    "Variable $\epsilon$-Greedy": (Greedy, {"eps_schedule": create_inverse_schedule(10)}),
    r"Softmax with $\tau=0.01$": (SoftmaxPolicy, {"temp": 0.01}),
    r"Softmax with $\tau=100$": (SoftmaxPolicy, {"temp": 100}),
    r"Variable $\tau$-Softmax": (SoftmaxPolicy, {"temp_schedule": create_inverse_schedule(10)}),
    "UCB with $C=1$": (UCB, {"C": 1}),
    "Thompson Sampling": (ThompsonSampling, {}),
    "Reinforce": (Reinforce, {"lr": 0.1}),
    "Reinforce with Baseline": (Reinforce, {"use_baseline": True, "lr": 0.1})
}

experiment = Experiment(
    algo, 
    "Bernoulli_2_every_case", 
    num_runs=1000, 
    num_arms=2, 
    metrics=[MeanCummulativeRegret(), PercentOptimalArmPull(), AverageRegretOverTime()]
)

# %%
experiment.simulate()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Expected Reward given an arm: [0.3745401188473625, 0.9507143064099162]
# 100%|██████████| 1000/1000 [04:49<00:00,  3.46it/s]

# %%
experiment.generate_plots()

# %%
for algo_name in algo:
    print(algo_name, experiment.results[algo_name]["metrics"]['Mean Cummulative Regret Over Time'][-1])
# Out:
# $\epsilon=0.3$-Greedy 87.33072160885631
# Variable $\epsilon$-Greedy 16.37487041052781
# Softmax with $\tau=0.01$ 13.047464477354149
# Softmax with $\tau=100$ 288.0853652587131
# Variable $\tau$-Softmax 7.326630969045444
# UCB with $C=1$ 9.537987500910537
# Thompson Sampling 2.4205077619502924
# Reinforce 38.664168856385146
# Reinforce with Baseline 38.49823069036723

# %% [markdown]
# ## Number of Arms K=5

# %%
algo = {
    "$\epsilon=0.3$-Greedy": (Greedy, {"eps": 0.3}),
    "Variable $\epsilon$-Greedy": (Greedy, {"eps_schedule": create_inverse_schedule(10)}),
    r"Softmax with $\tau=0.01$": (SoftmaxPolicy, {"temp": 0.01}),
    r"Softmax with $\tau=100$": (SoftmaxPolicy, {"temp": 100}),
    r"Variable $\tau$-Softmax": (SoftmaxPolicy, {"temp_schedule": create_inverse_schedule(10)}),
    "UCB with $C=1$": (UCB, {"C": 1}),
    "Thompson Sampling": (ThompsonSampling, {}),
    "Reinforce": (Reinforce, {"lr": 0.1}),
    "Reinforce with Baseline": (Reinforce, {"use_baseline": True, "lr": 0.1})
}

experiment = Experiment(
    algo, 
    "Bernoulli_5_every_case", 
    num_runs=1000, 
    num_arms=5, 
    metrics=[MeanCummulativeRegret(), PercentOptimalArmPull(), AverageRegretOverTime()]
)

# %%
experiment.simulate()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Expected Reward given an arm: [0.3745401188473625, 0.9507143064099162, 0.7319939418114051, 0.5986584841970366, 0.15601864044243652]
# 100%|██████████| 1000/1000 [04:49<00:00,  3.46it/s]

# %%
experiment.generate_plots()

# %%
for algo_name in algo:
    print(algo_name, experiment.results[algo_name]["metrics"]['Mean Cummulative Regret Over Time'][-1])
# Out:
# $\epsilon=0.3$-Greedy 120.03487414103968
# Variable $\epsilon$-Greedy 23.99809083796108
# Softmax with $\tau=0.01$ 29.717344129598857
# Softmax with $\tau=100$ 387.85289222783626
# Variable $\tau$-Softmax 18.191182164312025
# UCB with $C=1$ 45.01576400122853
# Thompson Sampling 10.790112712166222
# Reinforce 123.91555598505786
# Reinforce with Baseline 118.54859898200621

# %% [markdown]
# ## Number of Arms K=10

# %%
algo = {
    "$\epsilon=0.3$-Greedy": (Greedy, {"eps": 0.3}),
    "Variable $\epsilon$-Greedy": (Greedy, {"eps_schedule": create_inverse_schedule(10)}),
    r"Softmax with $\tau=0.01$": (SoftmaxPolicy, {"temp": 0.01}),
    r"Softmax with $\tau=100$": (SoftmaxPolicy, {"temp": 100}),
    r"Variable $\tau$-Softmax": (SoftmaxPolicy, {"temp_schedule": create_inverse_schedule(10)}),
    "UCB with $C=1$": (UCB, {"C": 1}),
    "Thompson Sampling": (ThompsonSampling, {}),
    "Reinforce": (Reinforce, {"lr": 0.1}),
    "Reinforce with Baseline": (Reinforce, {"use_baseline": True, "lr": 0.1})
}

experiment = Experiment(
    algo, 
    "Bernoulli_10_every_case", 
    num_runs=1000, 
    num_arms=10, 
    metrics=[MeanCummulativeRegret(), PercentOptimalArmPull(), AverageRegretOverTime()]
)

# %%
experiment.simulate()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Expected Reward given an arm: [0.3745401188473625, 0.9507143064099162, 0.7319939418114051, 0.5986584841970366, 0.15601864044243652, 0.15599452033620265, 0.05808361216819946, 0.8661761457749352, 0.6011150117432088, 0.7080725777960455]
# 100%|██████████| 1000/1000 [04:55<00:00,  3.38it/s]

# %%
experiment.generate_plots()

# %%
for algo_name in algo:
    print(algo_name, experiment.results[algo_name]["metrics"]['Mean Cummulative Regret Over Time'][-1])
# Out:
# $\epsilon=0.3$-Greedy 138.3110393144218
# Variable $\epsilon$-Greedy 37.98020306038743
# Softmax with $\tau=0.01$ 28.15562298058794
# Softmax with $\tau=100$ 429.2098760051859
# Variable $\tau$-Softmax 28.18650393475102
# UCB with $C=1$ 96.24483640604663
# Thompson Sampling 24.66162454121284
# Reinforce 173.50872103429225
# Reinforce with Baseline 173.69543971455664

# %% [markdown]
# # Normal Reward Distribution (with variance $\sigma^{2} = 0.01$)
# ## Number of Arms K=2

# %%
algo = {
    "$\epsilon=0.3$-Greedy": (Greedy, {"eps": 0.3}),
    "Variable $\epsilon$-Greedy": (Greedy, {"eps_schedule": create_inverse_schedule(10)}),
    r"Softmax with $\tau=0.01$": (SoftmaxPolicy, {"temp": 0.01}),
    r"Softmax with $\tau=100$": (SoftmaxPolicy, {"temp": 100}),
    r"Variable $\tau$-Softmax": (SoftmaxPolicy, {"temp_schedule": create_inverse_schedule(10)}),
    "UCB with $C=1$": (UCB1_Normal, {"C": 1}),
    "Thompson Sampling": (ThompsonSampling, {"prior_dist": Distribution.Normal}),
    "Reinforce": (Reinforce, {"lr": 0.1}),
    "Reinforce with Baseline": (Reinforce, {"use_baseline": True, "lr": 0.1})
}

experiment = Experiment(
    algo, 
    "Normal_2_0.01_every_case", 
    num_runs=1000, 
    num_arms=2, 
    metrics=[MeanCummulativeRegret(), PercentOptimalArmPull(), AverageRegretOverTime()],
    reward_dist=Normal
)

# %%
experiment.simulate()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Expected Reward given an arm: [0.3745401188473625, 0.9507143064099162]
# 100%|██████████| 1000/1000 [05:41<00:00,  2.93it/s]

# %%
experiment.generate_plots()

# %%
for algo_name in algo:
    print(algo_name, experiment.results[algo_name]["metrics"]['Mean Cummulative Regret Over Time'][-1])
# Out:
# $\epsilon=0.3$-Greedy 86.55231028145928
# Variable $\epsilon$-Greedy 16.259635573015288
# Softmax with $\tau=0.01$ 0.5761741875625553
# Softmax with $\tau=100$ 286.7918542076348
# Variable $\tau$-Softmax 7.070809629767657
# UCB with $C=1$ 32.26575450350338
# Thompson Sampling 0.5848168003759934
# Reinforce 37.72500493065817
# Reinforce with Baseline 38.302907640783374

# %% [markdown]
# ## Number of Arms K=5

# %%
algo = {
    "$\epsilon=0.3$-Greedy": (Greedy, {"eps": 0.3}),
    "Variable $\epsilon$-Greedy": (Greedy, {"eps_schedule": create_inverse_schedule(10)}),
    r"Softmax with $\tau=0.01$": (SoftmaxPolicy, {"temp": 0.01}),
    r"Softmax with $\tau=100$": (SoftmaxPolicy, {"temp": 100}),
    r"Variable $\tau$-Softmax": (SoftmaxPolicy, {"temp_schedule": create_inverse_schedule(10)}),
    "UCB with $C=1$": (UCB1_Normal, {"C": 1}),
    "Thompson Sampling": (ThompsonSampling, {"prior_dist": Distribution.Normal}),
    "Reinforce": (Reinforce, {"lr": 0.1}),
    "Reinforce with Baseline": (Reinforce, {"use_baseline": True, "lr": 0.1})
}

experiment = Experiment(
    algo, 
    "Normal_5_0.01_every_case", 
    num_runs=1000, 
    num_arms=5, 
    metrics=[MeanCummulativeRegret(), PercentOptimalArmPull(), AverageRegretOverTime()],
    reward_dist=Normal
)

# %%
experiment.simulate()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Expected Reward given an arm: [0.3745401188473625, 0.9507143064099162, 0.7319939418114051, 0.5986584841970366, 0.15601864044243652]
# 100%|██████████| 1000/1000 [05:50<00:00,  2.85it/s]

# %%
experiment.generate_plots()

# %%
for algo_name in algo:
    print(algo_name, experiment.results[algo_name]["metrics"]['Mean Cummulative Regret Over Time'][-1])
# Out:
# $\epsilon=0.3$-Greedy 117.83470457422692
# Variable $\epsilon$-Greedy 22.074044882713068
# Softmax with $\tau=0.01$ 2.2772215463803884
# Softmax with $\tau=100$ 387.75005022133575
# Variable $\tau$-Softmax 16.58725628554702
# UCB with $C=1$ 108.7321782591181
# Thompson Sampling 2.467287577724751
# Reinforce 131.88897555131572
# Reinforce with Baseline 116.30246309231663

# %% [markdown]
# ## Number of Arms K=10

# %%
algo = {
    "$\epsilon=0.3$-Greedy": (Greedy, {"eps": 0.3}),
    "Variable $\epsilon$-Greedy": (Greedy, {"eps_schedule": create_inverse_schedule(10)}),
    r"Softmax with $\tau=0.01$": (SoftmaxPolicy, {"temp": 0.01}),
    r"Softmax with $\tau=100$": (SoftmaxPolicy, {"temp": 100}),
    r"Variable $\tau$-Softmax": (SoftmaxPolicy, {"temp_schedule": create_inverse_schedule(10)}),
    "UCB with $C=1$": (UCB1_Normal, {"C": 1}),
    "Thompson Sampling": (ThompsonSampling, {"prior_dist": Distribution.Normal}),
    "Reinforce": (Reinforce, {"lr": 0.1}),
    "Reinforce with Baseline": (Reinforce, {"use_baseline": True, "lr": 0.1})
}

experiment = Experiment(
    algo, 
    "Normal_10_0.01_every_case", 
    num_runs=1000, 
    num_arms=10, 
    metrics=[MeanCummulativeRegret(), PercentOptimalArmPull(), AverageRegretOverTime()],
    reward_dist=Normal
)

# %%
experiment.simulate()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Expected Reward given an arm: [0.3745401188473625, 0.9507143064099162, 0.7319939418114051, 0.5986584841970366, 0.15601864044243652, 0.15599452033620265, 0.05808361216819946, 0.8661761457749352, 0.6011150117432088, 0.7080725777960455]
# 100%|██████████| 1000/1000 [05:57<00:00,  2.79it/s]

# %%
experiment.generate_plots()

# %%
for algo_name in algo:
    print(algo_name, experiment.results[algo_name]["metrics"]['Mean Cummulative Regret Over Time'][-1])
# Out:
# $\epsilon=0.3$-Greedy 132.5237477046436
# Variable $\epsilon$-Greedy 26.606971559737882
# Softmax with $\tau=0.01$ 9.226810157908666
# Softmax with $\tau=100$ 429.7833438079677
# Variable $\tau$-Softmax 24.028107836345857
# UCB with $C=1$ 241.97955740880624
# Thompson Sampling 6.312110376548137
# Reinforce 172.72651474596944
# Reinforce with Baseline 170.23086970021694

# %% [markdown]
# # An Interesting Case for Reinforce Algorithm

# %%
algo = {"Reinforce": (Reinforce, {"lr": 0.1}),
        "Reinforce with Baseline": (Reinforce, {"use_baseline": True, "lr": 0.1})}

experiment = Experiment(
    algo, 
    "Interesting_Reinforce", 
    num_runs=1000, 
    num_arms=10, 
    metrics=[MeanCummulativeRegret(), PercentOptimalArmPull(), AverageRegretOverTime()],
    reward_dist=Normal
)

# %%
experiment.simulate()
# Out:
# 100%|██████████| 1000/1000 [08:02<00:00,  2.07it/s]

# %%
experiment.generate_plots()

# %%
for algo_name in algo:
    print(algo_name, experiment.results[algo_name]["metrics"]['Mean Cummulative Regret Over Time'][-1])
# Out:
# Reinforce 271.07235397492474
# Reinforce with Baseline 164.42099041260653
